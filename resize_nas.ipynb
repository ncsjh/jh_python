# %%
import os
import shutil
import numpy as np
from glob import glob
import tensorflow as tf
from PIL import Image, ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

# %%
HERE=os.path.dirname(os.path.abspath(__file__))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 HERE=os.path.dirname(os.path.abspath(__file__))
#
# NameError: name '__file__' is not defined

# %%
def extCls(dir) -> list[str]:
    classes=os.listdir(HERE)
    classes.remove('resize_nas.py')
    return classes

# %% [markdown]
# cls=os.listdir(HERE)
# cls.remove('resize_nas.py')

# %%
def resize(cls : list) :
    for cl in cls:
    path=f'./Training/{cl}/'
    print(f'경로 : {path}')
    print(f'{cl} 폴더 내 파일 불러오기')
    li=os.listdir(path)
    print(f'{cl} 폴더 내 파일 리사이즈 시작')
    w=len(li)
    c=0
    for file in li:
        try:
            c+=1
            print('\r', int(c/w*100),'%', '  ', c,'/',w, file, end='')
            dest=path+file
            img=Image.open(dest)
            img=img.resize((600,600))
            img.save(dest)
        except:
            print(file, ' 파일에서 문제가 발생했습니다.')
            print('\r', int(c/w*100),'%', '  ', c,'/',w, file, end='')

# %% [markdown]
# for cl in cls:
#     path=f'./Training/{cl}/'
#     print(f'경로 : {path}')
#     print(f'{cl} 폴더 내 파일 불러오기')
#     li=os.listdir(path)
#     print(f'{cl} 폴더 내 파일 리사이즈 시작')
#     w=len(li)
#     c=0
#     for file in li:
#         try:
#             c+=1
#             print('\r', int(c/w*100),'%', '  ', c,'/',w, file, end='')
#             dest=path+file
#             img=Image.open(dest)
#             img=img.resize((600,600))
#             img.save(dest)
#         except:
#             print(file, ' 파일에서 문제가 발생했습니다.')
#             print('\r', int(c/w*100),'%', '  ', c,'/',w, file, end='')

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 with open('base.yaml') as f:
#       2     conf=yaml.load(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'base.yaml'

# %%
# !dir
# Out:
# 'ls'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
# 배치 파일이 아닙니다.

# %%
# Out:
#  1
